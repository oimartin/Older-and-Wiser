# %% [markdown]
# <a href="https://colab.research.google.com/github/oimartin/Older-and-Wiser/blob/medicare/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
total_area_19 = pd.read_csv('https://raw.githubusercontent.com/oimartin/Older-and-Wiser/medicare/data/2019_total_area_medicare_enrolled.csv')
total_area_20 = pd.read_csv('https://raw.githubusercontent.com/oimartin/Older-and-Wiser/medicare/data/2020_total_area_medicare_enrolled.csv')
total_demo_19 = pd.read_csv('https://raw.githubusercontent.com/oimartin/Older-and-Wiser/medicare/data/2019_total_demo_medicare_enrolled.csv')
total_demo_20 = pd.read_csv('https://raw.githubusercontent.com/oimartin/Older-and-Wiser/medicare/data/2020_total_demo_medicare_enrolled.csv')

# %%
area_totals = [total_area_19, total_area_20] 
demo_totals = [total_demo_19, total_demo_20]
[display(df.shape) for df in area_totals]
[display(df.shape) for df in demo_totals]
# Out:
# (242, 14)
# (245, 14)
# (223, 10)
# (223, 10)
# [None, None]

# %%
for df in area_totals:
  df.iloc[:, :-1].dropna(axis=0, inplace=True)
  # df.columns = df.iloc[0]
  display(df)
# Out:
#                                      MDCR ENROLL AB 24  \
# 0    Medicare Newly Enrolled Beneficiaries:  Total,...
# 1                                  Calendar Year 2019
# 2                                    Area of Residence
# 3                                                  NaN
# 4                                            All Areas
# ..                                                 ...
# 237                                                NaN
# 238                                                NaN
# 239                                                NaN
# 240                                                NaN
# 241                                                NaN
#
#                      Unnamed: 1                 Unnamed: 2  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
# 2    Part A and/or Part B Total  Part A and/or Part B Aged
# 3                           NaN                        NaN
# 4                     3,844,547                  3,258,338
# ..                          ...                        ...
# 237                         NaN                        NaN
# 238                         NaN                        NaN
# 239                         NaN                        NaN
# 240                         NaN                        NaN
# 241                         NaN                        NaN
#
#                         Unnamed: 3               Unnamed: 4  \
# 0                              NaN                      NaN
# 1                              NaN                      NaN
# 2    Part A and/or Part B Disabled  Part A and Part B Total
# 3                              NaN                      NaN
# 4                          586,209                2,605,121
# ..                             ...                      ...
# 237                            NaN                      NaN
# 238                            NaN                      NaN
# 239                            NaN                      NaN
# 240                            NaN                      NaN
# 241                            NaN                      NaN
#
#                  Unnamed: 5                  Unnamed: 6    Unnamed: 7  \
# 0                       NaN                         NaN           NaN
# 1                       NaN                         NaN           NaN
# 2    Part A and Part B Aged  Part A and Part B Disabled  Part A Total
# 3                       NaN                         NaN           NaN
# 4                 2,097,079                     508,042     3,764,626
# ..                      ...                         ...           ...
# 237                     NaN                         NaN           NaN
# 238                     NaN                         NaN           NaN
# 239                     NaN                         NaN           NaN
# 240                     NaN                         NaN           NaN
# 241                     NaN                         NaN           NaN
#
#       Unnamed: 8       Unnamed: 9   Unnamed: 10  Unnamed: 11      Unnamed: 12  \
# 0            NaN              NaN           NaN          NaN              NaN
# 1            NaN              NaN           NaN          NaN              NaN
# 2    Part A Aged  Part A Disabled  Part B Total  Part B Aged  Part B Disabled
# 3            NaN              NaN           NaN          NaN              NaN
# 4      3,179,188          585,438     2,685,042    2,176,229          508,813
# ..           ...              ...           ...          ...              ...
# 237          NaN              NaN           NaN          NaN              NaN
# 238          NaN              NaN           NaN          NaN              NaN
# 239          NaN              NaN           NaN          NaN              NaN
# 240          NaN              NaN           NaN          NaN              NaN
# 241          NaN              NaN           NaN          NaN              NaN
#
#      Unnamed: 13
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 237          NaN
# 238          NaN
# 239          NaN
# 240          NaN
# 241          NaN
#
# [242 rows x 14 columns]
#                                      MDCR ENROLL AB 24  \
# 0    Medicare Newly Enrolled Beneficiaries:  Total,...
# 1                                   Calendar Year 2020
# 2                                    Area of Residence
# 3                                                  NaN
# 4                                            All Areas
# ..                                                 ...
# 240                                                NaN
# 241                                                NaN
# 242                                                NaN
# 243                                                NaN
# 244                                                NaN
#
#                      Unnamed: 1                 Unnamed: 2  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
# 2    Part A and/or Part B Total  Part A and/or Part B Aged
# 3                           NaN                        NaN
# 4                     3,793,542                  3,230,917
# ..                          ...                        ...
# 240                         NaN                        NaN
# 241                         NaN                        NaN
# 242                         NaN                        NaN
# 243                         NaN                        NaN
# 244                         NaN                        NaN
#
#                         Unnamed: 3               Unnamed: 4  \
# 0                              NaN                      NaN
# 1                              NaN                      NaN
# 2    Part A and/or Part B Disabled  Part A and Part B Total
# 3                              NaN                      NaN
# 4                          562,625                2,611,370
# ..                             ...                      ...
# 240                            NaN                      NaN
# 241                            NaN                      NaN
# 242                            NaN                      NaN
# 243                            NaN                      NaN
# 244                            NaN                      NaN
#
#                  Unnamed: 5                  Unnamed: 6    Unnamed: 7  \
# 0                       NaN                         NaN           NaN
# 1                       NaN                         NaN           NaN
# 2    Part A and Part B Aged  Part A and Part B Disabled  Part A Total
# 3                       NaN                         NaN           NaN
# 4                 2,116,258                     495,112     3,730,050
# ..                      ...                         ...           ...
# 240                     NaN                         NaN           NaN
# 241                     NaN                         NaN           NaN
# 242                     NaN                         NaN           NaN
# 243                     NaN                         NaN           NaN
# 244                     NaN                         NaN           NaN
#
#       Unnamed: 8       Unnamed: 9   Unnamed: 10  Unnamed: 11      Unnamed: 12  \
# 0            NaN              NaN           NaN          NaN              NaN
# 1            NaN              NaN           NaN          NaN              NaN
# 2    Part A Aged  Part A Disabled  Part B Total  Part B Aged  Part B Disabled
# 3            NaN              NaN           NaN          NaN              NaN
# 4      3,167,973          562,077     2,674,862    2,179,202          495,660
# ..           ...              ...           ...          ...              ...
# 240          NaN              NaN           NaN          NaN              NaN
# 241          NaN              NaN           NaN          NaN              NaN
# 242          NaN              NaN           NaN          NaN              NaN
# 243          NaN              NaN           NaN          NaN              NaN
# 244          NaN              NaN           NaN          NaN              NaN
#
#      Unnamed: 13
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 240          NaN
# 241          NaN
# 242          NaN
# 243          NaN
# 244          NaN
#
# [245 rows x 14 columns]

# %%
total_area_19
# Out:
# 0   Medicare Newly Enrolled Beneficiaries:  Total, Aged, and Disabled Enrollees, by Area of Residence,   \
# 0    Medicare Newly Enrolled Beneficiaries:  Total,...
# 1                                  Calendar Year 2019
# 2                                    Area of Residence
# 3                                                  NaN
# 4                                            All Areas
# ..                                                 ...
# 237                                                NaN
# 238                                                NaN
# 239                                                NaN
# 240                                                NaN
# 241                                                NaN
#
# 0                           NaN                        NaN  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
# 2    Part A and/or Part B Total  Part A and/or Part B Aged
# 3                           NaN                        NaN
# 4                     3,844,547                  3,258,338
# ..                          ...                        ...
# 237                         NaN                        NaN
# 238                         NaN                        NaN
# 239                         NaN                        NaN
# 240                         NaN                        NaN
# 241                         NaN                        NaN
#
# 0                              NaN                      NaN  \
# 0                              NaN                      NaN
# 1                              NaN                      NaN
# 2    Part A and/or Part B Disabled  Part A and Part B Total
# 3                              NaN                      NaN
# 4                          586,209                2,605,121
# ..                             ...                      ...
# 237                            NaN                      NaN
# 238                            NaN                      NaN
# 239                            NaN                      NaN
# 240                            NaN                      NaN
# 241                            NaN                      NaN
#
# 0                       NaN                         NaN           NaN  \
# 0                       NaN                         NaN           NaN
# 1                       NaN                         NaN           NaN
# 2    Part A and Part B Aged  Part A and Part B Disabled  Part A Total
# 3                       NaN                         NaN           NaN
# 4                 2,097,079                     508,042     3,764,626
# ..                      ...                         ...           ...
# 237                     NaN                         NaN           NaN
# 238                     NaN                         NaN           NaN
# 239                     NaN                         NaN           NaN
# 240                     NaN                         NaN           NaN
# 241                     NaN                         NaN           NaN
#
# 0            NaN              NaN           NaN          NaN              NaN  \
# 0            NaN              NaN           NaN          NaN              NaN
# 1            NaN              NaN           NaN          NaN              NaN
# 2    Part A Aged  Part A Disabled  Part B Total  Part B Aged  Part B Disabled
# 3            NaN              NaN           NaN          NaN              NaN
# 4      3,179,188          585,438     2,685,042    2,176,229          508,813
# ..           ...              ...           ...          ...              ...
# 237          NaN              NaN           NaN          NaN              NaN
# 238          NaN              NaN           NaN          NaN              NaN
# 239          NaN              NaN           NaN          NaN              NaN
# 240          NaN              NaN           NaN          NaN              NaN
# 241          NaN              NaN           NaN          NaN              NaN
#
# 0    NaN
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# ..   ...
# 237  NaN
# 238  NaN
# 239  NaN
# 240  NaN
# 241  NaN
#
# [242 rows x 14 columns]

# %%
total_area_19.iloc[:,0]
# Out:
# 0      Medicare Newly Enrolled Beneficiaries:  Total,...
# 1                                    Calendar Year 2019
# 2                                      Area of Residence
# 3                                                    NaN
# 4                                              All Areas
#                              ...
# 237                                                  NaN
# 238                                                  NaN
# 239                                                  NaN
# 240                                                  NaN
# 241                                                  NaN
# Name: MDCR ENROLL AB 24, Length: 242, dtype: object

# %%
total_area_19.iloc[:, :-1].dropna(axis=0)
# Out:
#                              MDCR ENROLL AB 24                  Unnamed: 1  \
# 2                            Area of Residence  Part A and/or Part B Total
# 4                                    All Areas                   3,844,547
# 5                                United States                   3,787,304
# 7                                      Alabama                      59,821
# 8                                       Alaska                       8,402
# ..                                         ...                         ...
# 62                              American Samoa                         342
# 63                                        Guam                       1,430
# 64                    Northern Mariana Islands                         280
# 65  Foreign Countries and Other Outyling Areas                      23,126
# 66                                     Unknown                          22
#
#                    Unnamed: 2                     Unnamed: 3  \
# 2   Part A and/or Part B Aged  Part A and/or Part B Disabled
# 4                   3,258,338                        586,209
# 5                   3,208,541                        578,763
# 7                      46,012                         13,809
# 8                       7,454                            948
# ..                        ...                            ...
# 62                        212                            130
# 63                      1,195                            235
# 64                        228                             52
# 65                     22,624                            502
# 66                         22                              0
#
#                  Unnamed: 4              Unnamed: 5  \
# 2   Part A and Part B Total  Part A and Part B Aged
# 4                 2,605,121               2,097,079
# 5                 2,582,757               2,078,808
# 7                    44,011                  31,790
# 8                     5,548                   4,697
# ..                      ...                     ...
# 62                      222                     125
# 63                      736                     535
# 64                      176                     127
# 65                    1,309                   1,245
# 66                       11                      11
#
#                     Unnamed: 6    Unnamed: 7   Unnamed: 8       Unnamed: 9  \
# 2   Part A and Part B Disabled  Part A Total  Part A Aged  Part A Disabled
# 4                      508,042     3,764,626    3,179,188          585,438
# 5                      503,949     3,707,532    3,129,536          577,996
# 7                       12,221        59,025       45,228           13,797
# 8                          851         8,329        7,382              947
# ..                         ...           ...          ...              ...
# 62                          97           342          212              130
# 63                         201         1,420        1,185              235
# 64                          49           279          227               52
# 65                          64        23,112       22,610              502
# 66                           0            21           21                0
#
#      Unnamed: 10  Unnamed: 11      Unnamed: 12
# 2   Part B Total  Part B Aged  Part B Disabled
# 4      2,685,042    2,176,229          508,813
# 5      2,662,529    2,157,813          504,716
# 7         44,807       32,574           12,233
# 8          5,621        4,769              852
# ..           ...          ...              ...
# 62           222          125               97
# 63           746          545              201
# 64           177          128               49
# 65         1,323        1,259               64
# 66            12           12                0
#
# [62 rows x 13 columns]

# %%
[display(df) for df in area_totals]
# Out:
# 0   Medicare Newly Enrolled Beneficiaries:  Total, Aged, and Disabled Enrollees, by Area of Residence,   \
# 0    Medicare Newly Enrolled Beneficiaries:  Total,...
# 1                                  Calendar Year 2019
# 2                                    Area of Residence
# 3                                                  NaN
# 4                                            All Areas
# ..                                                 ...
# 237                                                NaN
# 238                                                NaN
# 239                                                NaN
# 240                                                NaN
# 241                                                NaN
#
# 0                           NaN                        NaN  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
# 2    Part A and/or Part B Total  Part A and/or Part B Aged
# 3                           NaN                        NaN
# 4                     3,844,547                  3,258,338
# ..                          ...                        ...
# 237                         NaN                        NaN
# 238                         NaN                        NaN
# 239                         NaN                        NaN
# 240                         NaN                        NaN
# 241                         NaN                        NaN
#
# 0                              NaN                      NaN  \
# 0                              NaN                      NaN
# 1                              NaN                      NaN
# 2    Part A and/or Part B Disabled  Part A and Part B Total
# 3                              NaN                      NaN
# 4                          586,209                2,605,121
# ..                             ...                      ...
# 237                            NaN                      NaN
# 238                            NaN                      NaN
# 239                            NaN                      NaN
# 240                            NaN                      NaN
# 241                            NaN                      NaN
#
# 0                       NaN                         NaN           NaN  \
# 0                       NaN                         NaN           NaN
# 1                       NaN                         NaN           NaN
# 2    Part A and Part B Aged  Part A and Part B Disabled  Part A Total
# 3                       NaN                         NaN           NaN
# 4                 2,097,079                     508,042     3,764,626
# ..                      ...                         ...           ...
# 237                     NaN                         NaN           NaN
# 238                     NaN                         NaN           NaN
# 239                     NaN                         NaN           NaN
# 240                     NaN                         NaN           NaN
# 241                     NaN                         NaN           NaN
#
# 0            NaN              NaN           NaN          NaN              NaN  \
# 0            NaN              NaN           NaN          NaN              NaN
# 1            NaN              NaN           NaN          NaN              NaN
# 2    Part A Aged  Part A Disabled  Part B Total  Part B Aged  Part B Disabled
# 3            NaN              NaN           NaN          NaN              NaN
# 4      3,179,188          585,438     2,685,042    2,176,229          508,813
# ..           ...              ...           ...          ...              ...
# 237          NaN              NaN           NaN          NaN              NaN
# 238          NaN              NaN           NaN          NaN              NaN
# 239          NaN              NaN           NaN          NaN              NaN
# 240          NaN              NaN           NaN          NaN              NaN
# 241          NaN              NaN           NaN          NaN              NaN
#
# 0    NaN
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# ..   ...
# 237  NaN
# 238  NaN
# 239  NaN
# 240  NaN
# 241  NaN
#
# [242 rows x 14 columns]
# 0   Medicare Newly Enrolled Beneficiaries:  Total, Aged, and Disabled Enrollees, by Area of Residence,  \
# 0    Medicare Newly Enrolled Beneficiaries:  Total,...
# 1                                   Calendar Year 2020
# 2                                    Area of Residence
# 3                                                  NaN
# 4                                            All Areas
# ..                                                 ...
# 240                                                NaN
# 241                                                NaN
# 242                                                NaN
# 243                                                NaN
# 244                                                NaN
#
# 0                           NaN                        NaN  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
# 2    Part A and/or Part B Total  Part A and/or Part B Aged
# 3                           NaN                        NaN
# 4                     3,793,542                  3,230,917
# ..                          ...                        ...
# 240                         NaN                        NaN
# 241                         NaN                        NaN
# 242                         NaN                        NaN
# 243                         NaN                        NaN
# 244                         NaN                        NaN
#
# 0                              NaN                      NaN  \
# 0                              NaN                      NaN
# 1                              NaN                      NaN
# 2    Part A and/or Part B Disabled  Part A and Part B Total
# 3                              NaN                      NaN
# 4                          562,625                2,611,370
# ..                             ...                      ...
# 240                            NaN                      NaN
# 241                            NaN                      NaN
# 242                            NaN                      NaN
# 243                            NaN                      NaN
# 244                            NaN                      NaN
#
# 0                       NaN                         NaN           NaN  \
# 0                       NaN                         NaN           NaN
# 1                       NaN                         NaN           NaN
# 2    Part A and Part B Aged  Part A and Part B Disabled  Part A Total
# 3                       NaN                         NaN           NaN
# 4                 2,116,258                     495,112     3,730,050
# ..                      ...                         ...           ...
# 240                     NaN                         NaN           NaN
# 241                     NaN                         NaN           NaN
# 242                     NaN                         NaN           NaN
# 243                     NaN                         NaN           NaN
# 244                     NaN                         NaN           NaN
#
# 0            NaN              NaN           NaN          NaN              NaN  \
# 0            NaN              NaN           NaN          NaN              NaN
# 1            NaN              NaN           NaN          NaN              NaN
# 2    Part A Aged  Part A Disabled  Part B Total  Part B Aged  Part B Disabled
# 3            NaN              NaN           NaN          NaN              NaN
# 4      3,167,973          562,077     2,674,862    2,179,202          495,660
# ..           ...              ...           ...          ...              ...
# 240          NaN              NaN           NaN          NaN              NaN
# 241          NaN              NaN           NaN          NaN              NaN
# 242          NaN              NaN           NaN          NaN              NaN
# 243          NaN              NaN           NaN          NaN              NaN
# 244          NaN              NaN           NaN          NaN              NaN
#
# 0    NaN
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# ..   ...
# 240  NaN
# 241  NaN
# 242  NaN
# 243  NaN
# 244  NaN
#
# [245 rows x 14 columns]
# [None, None]
